# %%
pwd
# Out:
# 'C:\\Users\\siddh\\MYSDA250\\Assignment-1-siddharth-purii'

# %%
def ling_task2(input):
    import os 
    import nltk
    from nltk import FreqDist
    from nltk.stem import PorterStemmer

    files = os.listdir(input)

    for f in files:
        if ".txt" in f:
            print(f + " - ")
            filePath = input + "/" + f
            rawData = open(filePath, encoding='latin').read()
            print("     Number of words = " + str(len(rawData)))
            print("     Lexical Diversity = " + str(len(set(rawData)) / len(rawData)))
            words = nltk.tokenize.word_tokenize(rawData)
            print("     Top 10 most frequent words and their counts = ")
            for i in FreqDist(words).most_common(10):
                print("          " + str(i))
            tenCharacter = []
            for w in words:
                if len(w)>10:
                    tenCharacter.append(w)
            print("     Words that are at least 10 characters long and their counts = ")
            for i in FreqDist(tenCharacter).most_common():
                print("          " + str(i))
            sentences = nltk.sent_tokenize(rawData)
            longestSentence = (max(sentences, key=len)).split()
            print('     This is the longest sentence in the text, with ' + str(len(max(sentences, key=len))) + ' words' + ' = ')
            print("          " + max(sentences, key=len))
            print("     Here is a stemmed version of the longest sentence = ")
            stemmer = PorterStemmer()
            for word in longestSentence:
                i = ((word,stemmer.stem(word)))
                print("          " + str(i))
            print(" ")
            print(" ")
        else:
            print("None")

filepath = "./data"            
ling_task2(filepath)
# Out:
# Movie Corpus Exerpt.txt -
#      Number of words = 361526
#      Lexical Diversity = 0.00022128422298811151
#      Top 10 most frequent words and their counts =
#           ('.', 7646)
#           (',', 4592)
#           ('@', 4402)
#           ('-', 2927)
#           ('I', 2506)
#           ('you', 2284)
#           ('?', 1912)
#           ('the', 1590)
#           ('to', 1431)
#           ("'s", 1358)
#      Words that are at least 10 characters long and their counts =
#           ('interesting', 11)
#           ('Confederate', 9)
#           ('Congratulations', 6)
#           ('investigation', 6)
#           ('compartment', 5)
#           ('Londonderry', 4)
#           ('circumference', 4)
#           ('neighborhood', 4)
#           ('instructions', 4)
#           ('Contradiction', 4)
#           ('compliments', 4)
#           ('responsibility', 4)
#           ('circumstances', 4)
#           ('Grandfather', 4)
#           ('explanation', 4)
#           ('sarsaparilla', 3)
# ...
